# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import datasets, model_selection, linear_model, metrics
import os

# %% [markdown]
# **Data:**
# There are 23 features for each user, which are discribed below
#
# **id**: A unique Id field which represents a customer
#
# **X1**: Credit line
#
# **X2**: Gender (1 = male; 2 = female).
#
# **X3**: Education (1 = graduate school; 2 = university; 3 = high school; 4 = others).
#
# **X4**: Marital status (1 = married; 2 = single; 3 = others).
#
# **X5**: Age (year).
#
# **X6 - X11**: History of past payment.
#
# **X6** = September, 2015;
#
# **X7** = August, 2015;
#
# **...**
#
# **X11** =April, 2015; where -1 = pay one month ahead; -2 = pay two month ahead; 0 = pay on time; Positive means the payment delayed months, 1 = delay 1 month, 2 = delay 2 months, etc.
#
# **X12- X17**: Amount in bill statement.
#
# **X12** = amount of bill statement September, 2015
#
# **X13** = amount of bill statement August, 2015
#
# **...**
#
# **X17** = amount of bill statement April, 2015.
#
# **X18-X23**: Amount of previous payment
#
# **X18** = amount paid in September, 2015;
#
# **X19** = amount paid in August, 2015;
#
# **...**
#
# **X23** = amount paid in April, 2015.
#
# **Y**: Whether the customer is creditable (1) or not (0).

# %%
test3 = pd.read_csv('/Users/Rockwell/Desktop/Bank-Fraud-Detection/train.csv')
test3
# Out:
#           id      X1  X2  X3  X4  X5  X6  X7  X8  X9  ...     X15     X16  \
# 0          1  200000   2   3   1  53   0   0   0   0  ...  133207  136159
# 1          2  130000   2   3   2  39   0   0   0   2  ...  130814  130758
# 2          3  350000   2   1   2  41   0   0   0   0  ...  119947  117328
# 3          4  240000   2   2   1  43   1  -2  -2  -1  ...   12700   12500
# 4          5  180000   1   2   2  28  -1  -1  -1  -1  ...     332     416
# ...      ...     ...  ..  ..  ..  ..  ..  ..  ..  ..  ...     ...     ...
# 24995  24996  300000   2   1   1  56   1  -2  -2  -2  ...       0       0
# 24996  24997  230000   2   2   1  36   0   0   0   2  ...     631    1635
# 24997  24998   30000   2   2   2  23   2   2   2   2  ...   41931   38638
# 24998  24999  360000   1   1   1  36   0   0   0   0  ...   36491   41179
# 24999  25000  320000   2   1   2  41  -2  -2  -2  -2  ...   11970    9700
#
#           X17   X18    X19    X20   X21    X22    X23  Y
# 0      138741  6500   5000   5000  5100   5000   5400  0
# 1      123468  7500  10000      0  4500   4500   4179  0
# 2      118400  6000   5900   5800  4100   4500   5000  0
# 3       26225     0      0  12700     0  13725      0  0
# 4         416     0    416    332   500   3500    832  0
# ...       ...   ...    ...    ...   ...    ...    ... ..
# 24995       0     0      0      0     0      0      0  1
# 24996   10244  3000   2023      0  1004  10019   1141  0
# 24997   35343     0   1800   9851     0   1183   5132  0
# 24998   45823  3000   3000   3000  5000   5000   5000  0
# 24999   38473  1376   3343  11973  9700  38473  29757  0
#
# [25000 rows x 25 columns]

# %%
test2 = pd.read_csv('/Users/Rockwell/Desktop/Bank-Fraud-Detection/test.csv')
test2
# Out:
#          id      X1  X2  X3  X4  X5  X6  X7  X8  X9  ...     X14     X15  \
# 0     25001  180000   1   1   2  27  -1   0   0   0  ...    6482    3246
# 1     25002  230000   2   3   1  52  -2  -2  -2  -2  ...    2233    1410
# 2     25003  150000   2   1   2  28  -1  -1   2  -1  ...    1159    1159
# 3     25004  160000   1   1   1  40   0   0   2   2  ...    3503    -473
# 4     25005   20000   2   2   2  26   0   0   0   0  ...    8515    6584
# ...     ...     ...  ..  ..  ..  ..  ..  ..  ..  ..  ...     ...     ...
# 4995  29996  120000   2   1   2  25  -1  -1  -1  -1  ...    3938    1110
# 4996  29997  200000   2   2   1  39   0   0   2   0  ...  149765  131741
# 4997  29998  370000   1   1   2  30   0   0   0   0  ...  285705  295747
# 4998  29999   20000   1   2   1  35   1   2   2   0  ...   20018   20427
# 4999  30000  110000   1   1   2  33   0   0   0   0  ...   87889   61123
#
#          X16     X17    X18    X19    X20    X21    X22    X23
# 0       2016    2334  12000   5004   1000   1000   2300   3000
# 1          0       0   3939   2244   1421      0      0    236
# 2      11476   10249   2468      0   1159  11476      0   2034
# 3       3757    3286   3000      0      0   4700      0   3000
# 4       3403    3748   2600   1500   1500   1000    402      0
# ...      ...     ...    ...    ...    ...    ...    ...    ...
# 4995    9848    3301  12557   3938   1110   9848   3301      0
# 4996  134488  137240   9201   5000   4500   4600   4700   5319
# 4997  250158  255956  13000  11000  15000  10000  10000  12000
# 4998   19377   19386   1000   1000   1000   1500    900   1000
# 4999   59395   52189   4000   5009   4000   3027   3000   2500
#
# [5000 rows x 24 columns]

# %%
test1 = pd.read_csv('/Users/Rockwell/Desktop/Bank-Fraud-Detection/sampleSubmission.csv')
test1
# Out:
#          id   y
# 0     25001 NaN
# 1     25002 NaN
# 2     25003 NaN
# 3     25004 NaN
# 4     25005 NaN
# ...     ...  ..
# 4995  29996 NaN
# 4996  29997 NaN
# 4997  29998 NaN
# 4998  29999 NaN
# 4999  30000 NaN
#
# [5000 rows x 2 columns]
